# %%
import asyncio
import aiohttp
import pandas as pd
import time
from goplus.token import Token

# %% [markdown]
# # Counterfeit token transfers

# %% [markdown]
# ### Script used to find counterfeit USDT & USDC tokens
#
# ```sql
# WITH
#   lookalikes AS (
#     SELECT
#       address AS token_address,
#       name,
#       symbol
#     FROM
#       `bigquery-public-data`.crypto_ethereum.tokens
#     WHERE
#       (REGEXP_CONTAINS(symbol, r'(?i)usdt|usdc') OR REGEXP_CONTAINS(symbol, r'(?i)^([0OÞ]+[.:]?[ -]?)?u[5s$]+[.: -]?[dt][t7]+') OR
#       REGEXP_CONTAINS(symbol, r'(?i)^([0OÞ]+[.:]?[ -]?)?u[5s$]+[.: -]?[dc][.:]?[c7]?') OR REGEXP_CONTAINS(symbol,
#         r'(?i)([UУ][5ЅS$][DĐ])[TТ7]|[UУ][5ЅS$][DĐ][СC]') OR symbol LIKE '%USDТ%' OR symbol LIKE '%USDT%' OR
#       symbol LIKE '%USDС%' OR symbol LIKE '%USDC%' OR REGEXP_CONTAINS(symbol, r'(?i)(usdt|usdc).*(gift|earn|bonus|claim|airdrop|reward|2\.0|202[4-9]|v2|new|official|pro|max|global|finance|pay|cash|eth|bridge|swap)') OR
#       REGEXP_CONTAINS(symbol, r'(?i)tdsu|cdsu|tusd|cusd') OR REGEXP_CONTAINS(symbol, r'(?i)⊙|Ⓤ|usd[tс] ?⊗|usdt *⊸|usdc *©|usdt *™') OR
#       REGEXP_CONTAINS(symbol, r'[\x{200B}-\x{200D}\x{2060}\x{180E}\x{00AD}\x{200E}\x{200F}\x{202A}-\x{202E}\x{2066}-\x{2069}]')) AND
#       UPPER(symbol) NOT IN ('USDC', 'USDT', 'WUSDC', 'AUSDC', 'CUSDC', 'CUSDT', 'STGUSDC') AND UPPER(name) NOT LIKE '%CIRCLE%'
#       -- actual USDC, Addressse
#     AND address NOT IN (
#       # test
#       '0xdac17f958d2ee523a2206206994597c13d831ec7',  # Ethereum USDT
#
#     # USDC (Circle)
#     '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',  # Ethereum native USDC
#     '0x8ac76a51cc950d9822d68b83fe1ad97b32cd580d',  # Ethereum USDC.e (bridged)
#
#     # Base USDC
#     '0x1c7d4b196cb0c7b01d743fbc6116a902379c7238'
#     )
#   )
# SELECT DISTINCT
#   l.token_address,
#   l.name,
#   l.symbol
# FROM
#   lookalikes AS l
#   INNER JOIN
#   `bigquery-public-data`.crypto_ethereum.token_transfers AS t
#   ON LOWER(t.token_address) = LOWER(l.token_address)
# WHERE
#   t.block_timestamp >= TIMESTAMP("2024-07-01") AND t.block_timestamp < TIMESTAMP("2025-11-01")
# ORDER BY l.symbol;
#
# ```

# %% [markdown]
# ### Find true positives in counterfeit token set

# %%
# Candidate Counterfeit tokens from 7/24 to 10/25
CANDIDATES = "data/candidate_counterfeit_tokens.csv"

# Read CSV
raw_candiates = pd.read_csv(CANDIDATES)
# Go plus labs API config
client = Token(access_token=None)
CHAIN_ID = "1"

# %%
# sample
response = client.token_security(chain_id=CHAIN_ID, addresses=['0xdeff2caab5afd843b5be40358edc743571fb54e75ee6c25e2a050d47381bebb8'])
result_dict = response.result  # this MUST be a dict
# first_key = next(iter(result_dict))
# data = result_dict[first_key]
# print(response)
# creator_address
print(response)
# print(response)
# Out:
# {'code': 1, 'message': 'OK', 'result': None}

# %%
# Helper function that calls the token_security endpoint given an address

MAX_PER_MIN = 20        # rate limit
semaphore = asyncio.Semaphore(MAX_PER_MIN)

async def check_token(addr):
    async with semaphore:
        try:
            response = client.token_security(chain_id=CHAIN_ID, addresses=[addr])
            # access the result with the SDK wrapper
            info = response.result
            first_key = next(iter(info))
            data = info[first_key]
            if response.message != "OK" or data is None:
                print("-----failed to get data for", addr, "-------")
                print("first key", first_key)
                print("message", response.message)
                print(response)
                return None
            elif data.fake_token is None:
                print(addr,"was not labeled a scam")
                return None
            # scam case 
            print(addr, "was labeled a scam")
            row = {
                "token_address": addr,
                "token_symbol": data.token_symbol,
                "creator_address": data.creator_address,
                "is_airdrop_scam": data.is_airdrop_scam,
                "is_honeypot": data.is_honeypot,
            }

            return row

        except Exception as e:
            print(f"ERROR on {addr}: {e}")
            return {"token_address": addr, "error": str(e)}

# %%
addresses = raw_candiates["token_address"].astype(str).str.lower().unique().tolist()
tasks = [check_token(addr) for addr in addresses]

print(f"Checking {len(tasks)} tokens (30/min)...")

results = []
for i in range(0, len(tasks), MAX_PER_MIN):
    batch = tasks[i:i + MAX_PER_MIN]
    print(f"Processing {i//MAX_PER_MIN + 1}/{(len(tasks)-1)//MAX_PER_MIN + 1} batch...")
    results.extend(await asyncio.gather(*batch))
    if i + MAX_PER_MIN < len(tasks):
        print("Sleeping 60s for rate limit...")
        await asyncio.sleep(60)

# filter out None rows
results = [r for r in results if r is not None]

df = pd.DataFrame(results)
# Out:
# Checking 111 tokens (30/min)...
# Processing 1/6 batch...
# 0xcd5fb50c82590b9d11474ff19d085eba3c483e57 was not labeled a scam
# 0xeea6a9166a382db43cf429e6b232a6666332ef4c was not labeled a scam
# 0x479763d77cb82155a27fbb94c11f055064473e17 was labeled a scam
# 0x64a308881990c70826676b908e54054fac0f1a96 was labeled a scam
# 0x76251603b6c7df8d06e7fade0c47ccc1d31d801c was labeled a scam
# 0xae2b2b6b879caf2cf9340e0b96901973590654b6 was labeled a scam
# 0xd6a94978a51796e0b570446f5fe6f616fe08a4f2 was labeled a scam
# 0x6b951017a3212edc6b275976bfdd50969f6e1c62 was not labeled a scam
# 0x48d984dad97e29590e131598d0b27d5d49eaaeac was not labeled a scam
# 0x3242aebcdcf8de491004b1c98e6595e9827f6c17 was not labeled a scam
# 0x4827e558e642861cd7a1c8f011b2b4661f8d51fa was not labeled a scam
# 0xa861518c1be7e7aae65f203d6cbe23e2612c0fc3 was not labeled a scam
# 0x21efeb62dc81659a09786a57e75aeee43aaf4889 was not labeled a scam
# 0xa33ace59e4b0d9a45cd4a3f0dbab86d87bdd67e2 was not labeled a scam
# 0xe37afa3aa95e153b8dd0fe8456cbf345cb4c51f7 was not labeled a scam
# 0x09b5e5b9e5682b94ccdc367b8ee48a48ad1aaad9 was not labeled a scam
# 0xc2f256382db296244420746d82b5895ec284c9e6 was not labeled a scam
# 0x5266cf7ca32aa0c394d90acc6eca9722eaeca176 was not labeled a scam
# 0xf79e4294f721caec2d5a5b6ef59f580ea572e814 was not labeled a scam
# 0x84d63b29f2c66785e7c33a538e72990a3ac30258 was not labeled a scam
# Sleeping 60s for rate limit...
# Processing 2/6 batch...
# 0xdfc2945549a1fe17201997223ca4c36bf463f843 was not labeled a scam
# 0x40477ca2ad46cc037a6860eb299d300fecc9997c was not labeled a scam
# 0x22a39c2dd54b71ac884657bb3e37308abe2d02e1 was not labeled a scam
# 0xf3c1f75e58a114bde1940be7e4f63af6b35817fc was not labeled a scam
# 0x7ad9335e172d3dd5f410fb44e43597f26374b2a5 was not labeled a scam
# 0x0653e11b1674958704be64f78c2701ec814e4677 was not labeled a scam
# 0x6ca9d0b650c7a4b3871ea898b9f1a7fd27fb1d58 was not labeled a scam
# 0x846bd426e8b85ddddcaf56b1ea1f35801dc275c5 was not labeled a scam
# 0xf6c0aa7ebfe9992200c67e5388e4f42da49e1783 was not labeled a scam
# 0x3c7b464376db7c9927930cf50eefdea2eff3a66a was not labeled a scam
# 0x9ec1f743d192f524a9cceafdf838a042426aaf0e was not labeled a scam
# 0x309627af60f0926daa6041b8279484312f2bf060 was not labeled a scam
# 0xd1146b08e8104eedba44a73b7bda1d102c6cedc9 was not labeled a scam
# 0xb7c6338e83746250116250c27eb610971be8a5f7 was not labeled a scam
# 0x861d899e74ec0e84fa8a15ba58088bb3baccb6fa was not labeled a scam
# 0x3e3c78ed62903bb6b6be7b303b32f247a67f6c29 was not labeled a scam
# 0xb0399c2fb7958d8d0fde93ec58c4efa1ba501375 was not labeled a scam
# 0xbd62253c8033f3907c0800780662eab7378a4b96 was not labeled a scam
# 0x51afee9c1133fad23f8cb675b7ee29d2f267c841 was not labeled a scam
# 0x89c08383442efe6a88a87a095a37fee274b9d9a7 was not labeled a scam
# Sleeping 60s for rate limit...
# Processing 3/6 batch...
# 0xef31ff997e810acab2e044b49893598fef4e90c4 was not labeled a scam
# 0x4954db6391f4feb5468b6b943d4935353596aec9 was not labeled a scam
# 0xa4bdb11dc0a2bec88d24a3aa1e6bb17201112ebe was not labeled a scam
# 0xa1329011757d1df0727f513b1cef1e4c8ff8cd3d was not labeled a scam
# 0x4a6c77c17a76ecf3da752a975200984411fa0cb9 was not labeled a scam
# 0xbd96572c5d927572a7d35086e8632f1ebbb667df was not labeled a scam
# 0x739392ed4d76be412084b971751c0502965d2ad3 was not labeled a scam
# 0x5053a911d1ae116ab49f7e08b39ca8a4d94a5c0a was not labeled a scam
# 0x7e4fb5cdffc96f28d085f74a96903b1e4a79b537 was not labeled a scam
# 0xd35ae5e7d38b3ca0eac35d20366c26c9bd65c122 was not labeled a scam
# 0x7461bfa069ad74ca4a084ce6258bad29c4b810e8 was not labeled a scam
# 0x1445c9a6c00b20c9d47611cf57b26b41954de205 was not labeled a scam
# 0x1879550f89dd4fa6ebadca4f242fa73944b9c288 was not labeled a scam
# 0xe989cc33ad28348adc9fd78d509e7bb7a04ddf0d was not labeled a scam
# 0x7960f2635667dca2d0ddcc44b4c5e47dc93707a1 was not labeled a scam
# 0xed8934f8e4ea39c6761e14c2b49f43a78b8def4b was not labeled a scam
# 0xd6f6c37154040a8eb022f1c304f47233f52ad95b was not labeled a scam
# 0x5365b5bc56493f08a38e5eb08e36cbbe6fcc8306 was not labeled a scam
# 0xfb54b48f61b7e20d6e20b2d013044e26d347d4c0 was not labeled a scam
# 0xe9e8fe77b4611691dfe51551629916e00460fa8d was not labeled a scam
# Sleeping 60s for rate limit...
# Processing 4/6 batch...
# 0xbe232db8634554208e09df7df8140a70d6ba07b1 was not labeled a scam
# 0x2d3feb9800acc1bd1c2224b1d33de85112d2594e was not labeled a scam
# 0x0ee853550d97b42e5e832b2e216271fe69ddcd45 was labeled a scam
# 0x04555b4f4b09aca3c0d0523ec95535376c58ce57 was not labeled a scam
# 0x5f8980ec3b79783f3fb77ab2d8c5eaa44c268b95 was not labeled a scam
# 0xe4b70f9ddbb286f3cfa836e0fd970479f3193252 was not labeled a scam
# 0x866dbf56c518c1ed46fcd215285be43e7c1ad928 was not labeled a scam
# 0x5cc676c82ef59252a2c87b0e7d6a27b6b1241117 was not labeled a scam
# 0x5541b24cf410a081f550a2f7ac7141d7e2080e27 was not labeled a scam
# 0xc6e9d9a2663879add56acef4dd2e04b2ce1c04f6 was labeled a scam
# 0xf3135c779ce72c9b67afa853c3a8699242826ed7 was labeled a scam
# 0x3784b5d7b9256a8ec773d4bceab7b1abdc5c5aba was labeled a scam
# 0xd6ba0c40f6e29747086a1edbb7299852fae40707 was labeled a scam
# 0xae7ba4a75b3c2781e8937526372f731a21adce3b was labeled a scam
# 0x1d70eae23db8c98b5e2a7746110aa49373c0ebd0 was labeled a scam
# 0x07a5ef57368b06aff083e7ff2e48427f4625eb53 was labeled a scam
# 0xe39b7982d628edff39f9cc4c7b98d92eb75baa38 was labeled a scam
# 0x0755bf4a88cf59aded7f8800ef34cca8a8105cfe was not labeled a scam
# 0xb961b84c7bea4a4a30db6a5bbab54765e7a9c203 was not labeled a scam
# 0xe3cc1c55a5755463a6296be995e0398733196913 was not labeled a scam
# Sleeping 60s for rate limit...
# Processing 5/6 batch...
# 0x5dcdf0633f829ceaa8feb7c21afc3212328828dd was not labeled a scam
# 0x771e0efc1a767ebb6aa694eb8bcfccc657811601 was not labeled a scam
# 0x65c8c0bda98860bdd8de0aa649b25bb13a486f1c was not labeled a scam
# 0xf64834819a0014fb4167c0aa344a68e9dd7fc0b4 was not labeled a scam
# 0x73741f1882766e6ab92a0d61e06b421dda3aacfb was not labeled a scam
# 0xd484d1697c4e21253c66d3f7536259c141394bfe was not labeled a scam
# 0x78b01ff3bc9d2393dbfc880e3e50ec6e39c5fd56 was not labeled a scam
# 0x9f65af5529f0c15f782dce303b34efa96c8fb4ec was not labeled a scam
# 0x664fe8f29d976c1e8310d94d229bacd977962f25 was not labeled a scam
# 0xdaa2ce2fce03104a37ef30076b4372fa3911132e was not labeled a scam
# 0xafe9f2fe17b1724461f4939b6bc43fd26a0af2b9 was not labeled a scam
# 0xe384af9815a78b1d9587813b62a025684a363246 was not labeled a scam
# 0xf60e2eef63f35de700ca55bf30b24902cbc17d0c was not labeled a scam
# 0x4bfcd80e3ccf58bb97f6ca8be1aff948fb82d818 was not labeled a scam
# 0xe53445ed0c4227a5e064f689f6e9a1364fcfec4d was not labeled a scam
# 0x0816a5540130e8bfb3c133238afdfde43d79aa61 was not labeled a scam
# 0xb1479fb8eb51ba67099734f243d6610ecb7d39bd was not labeled a scam
# 0xfd53ca92811f8ee958f72756542c578079f3e437 was not labeled a scam
# 0xf75324293dd1bbf2b923d18c1f82b98b7632d4d8 was not labeled a scam
# 0x11dc51f0e423fe412f3eec1a24b261254ace6cb0 was not labeled a scam
# Sleeping 60s for rate limit...
# Processing 6/6 batch...
# 0x56fffb42058e5dc12566b973bf15a99919683605 was not labeled a scam
# 0x0749acbfd92beedf166e22ad9f76a150e3f2b1a0 was not labeled a scam
# 0x67e4e8e4e5911ef1ab9eeedf646d86d58c937a17 was not labeled a scam
# 0x790d49eb9a8fc9f8db47e0f005354e62e262caf9 was not labeled a scam
# 0x02306b1ba9b981d8c0706311df92ca66a0bfaf82 was not labeled a scam
# 0x27a08470c5a21dbd32358c35e747e784fc0d6e39 was not labeled a scam
# 0x53744e2990dcfc0418be0fda5feb7241e144da45 was not labeled a scam
# 0x0c1a7cfc840c7e3c5ef2ab12e41550976acda34b was not labeled a scam
# 0x0e26eaf6d4deb717ac22e67a306af3cb2cdb7bf2 was not labeled a scam
# 0x70b6b81a93f57cdfda8f0320fa189fb37b644bee was not labeled a scam
# 0x1205104657a5d625c8d73636b027b1bd65ec8cdc was not labeled a scam

# %%
df
# Out:
#                                  token_address token_symbol  \
# 0   0x479763d77cb82155a27fbb94c11f055064473e17        B᠎N᠎B
# 1   0x64a308881990c70826676b908e54054fac0f1a96        B᠎Ν᠎B
# 2   0x76251603b6c7df8d06e7fade0c47ccc1d31d801c        B᠎Ν᠎B
# 3   0xae2b2b6b879caf2cf9340e0b96901973590654b6        B᠎Ν᠎B
# 4   0xd6a94978a51796e0b570446f5fe6f616fe08a4f2        B᠎Ν᠎B
# 5   0x0ee853550d97b42e5e832b2e216271fe69ddcd45        USDT­
# 6   0xc6e9d9a2663879add56acef4dd2e04b2ce1c04f6         USDŦ
# 7   0xf3135c779ce72c9b67afa853c3a8699242826ed7         USDŦ
# 8   0x3784b5d7b9256a8ec773d4bceab7b1abdc5c5aba         USDС
# 9   0xd6ba0c40f6e29747086a1edbb7299852fae40707         USDС
# 10  0xae7ba4a75b3c2781e8937526372f731a21adce3b         USDС
# 11  0x1d70eae23db8c98b5e2a7746110aa49373c0ebd0         USDТ
# 12  0x07a5ef57368b06aff083e7ff2e48427f4625eb53         USDТ
# 13  0xe39b7982d628edff39f9cc4c7b98d92eb75baa38         USDТ
#
#                                creator_address is_airdrop_scam is_honeypot
# 0   0x756ea0e357c9dca2e8bbb7ac53bb7537a2861099            None           0
# 1   0x756ea0e357c9dca2e8bbb7ac53bb7537a2861099            None           0
# 2   0x78b7fa4b19268ee10e3a3bd7aada077ba7888888            None           0
# 3   0x0daa4798ee696ffb75f660ec8c4d1a87d7666666            None           0
# 4   0xccb9b9db0ca22ed3781f19a9d2583dfe7a000000            None           0
# 5   0xbaf4fed85bbd89616973bc6ee3679640bbc4c4d4            None           0
# 6   0x9ce533cab5d8428d777bb603d753be423396cbc1            None        None
# 7   0x9ce533cab5d8428d777bb603d753be423396cbc1            None           0
# 8   0x9872a42904f831e1b83f73815f11766ebf64c604            None        None
# 9   0x702659cdeca87552fb445b7ab9146c9568bae1d8            None        None
# 10  0x069823086a326de10b730cb31c1eb62ae75fd630            None        None
# 11  0x9872a42904f831e1b83f73815f11766ebf64c604            None        None
# 12  0x702659cdeca87552fb445b7ab9146c9568bae1d8            None        None
# 13  0x069823086a326de10b730cb31c1eb62ae75fd630            None        None

# %%
df.to_csv("data/counterfeit_tokens.csv", index=False)
